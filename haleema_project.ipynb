# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df1 = pd.read_csv('2015-building-energy-benchmarking.csv')

# %%
df1.head()
# Out:
#    OSEBuildingID  DataYear    BuildingType PrimaryPropertyType  \
# 0              1      2015  NonResidential               Hotel
# 1              2      2015  NonResidential               Hotel
# 2              3      2015  NonResidential               Hotel
# 3              5      2015  NonResidential               Hotel
# 4              8      2015  NonResidential               Hotel
#
#             PropertyName TaxParcelIdentificationNumber  \
# 0   MAYFLOWER PARK HOTEL                     659000030
# 1        PARAMOUNT HOTEL                     659000220
# 2           WESTIN HOTEL                     659000475
# 3              HOTEL MAX                     659000640
# 4  WARWICK SEATTLE HOTEL                     659000970
#
#                                             Location  CouncilDistrictCode  \
# 0  {'latitude': '47.61219025', 'longitude': '-122...                    7
# 1  {'latitude': '47.61310583', 'longitude': '-122...                    7
# ...

# %%
df1.isnull()
# Out:
#       OSEBuildingID  DataYear  BuildingType  PrimaryPropertyType  \
# 0             False     False         False                False
# 1             False     False         False                False
# 2             False     False         False                False
# 3             False     False         False                False
# 4             False     False         False                False
# ...             ...       ...           ...                  ...
# 3335          False     False         False                False
# 3336          False     False         False                False
# 3337          False     False         False                False
# 3338          False     False         False                False
# 3339          False     False         False                False
#
#       PropertyName  TaxParcelIdentificationNumber  Location  \
# 0            False                          False     False
# 1            False                          False     False
# ...

# %%
col = df1.columns       # .columns gives columns names in data 
print(col)
# Out:
# Index(['OSEBuildingID', 'DataYear', 'BuildingType', 'PrimaryPropertyType',
#        'PropertyName', 'TaxParcelIdentificationNumber', 'Location',
#        'CouncilDistrictCode', 'Neighborhood', 'YearBuilt', 'NumberofBuildings',
#        'NumberofFloors', 'PropertyGFATotal', 'PropertyGFAParking',
#        'PropertyGFABuilding(s)', 'ListOfAllPropertyUseTypes',
#        'LargestPropertyUseType', 'LargestPropertyUseTypeGFA',
#        'SecondLargestPropertyUseType', 'SecondLargestPropertyUseTypeGFA',
#        'ThirdLargestPropertyUseType', 'ThirdLargestPropertyUseTypeGFA',
#        'YearsENERGYSTARCertified', 'ENERGYSTARScore', 'SiteEUI(kBtu/sf)',
#        'SiteEUIWN(kBtu/sf)', 'SourceEUI(kBtu/sf)', 'SourceEUIWN(kBtu/sf)',
#        'SiteEnergyUse(kBtu)', 'SiteEnergyUseWN(kBtu)', 'SteamUse(kBtu)',
#        'Electricity(kWh)', 'Electricity(kBtu)', 'NaturalGas(therms)',
#        'NaturalGas(kBtu)', 'OtherFuelUse(kBtu)',
# ...

# %%
y = df1.OSEBuildingID                        
list = ['Zip Codes','OSEBuildingID']
x = df1.drop(list,axis = 1 )
x.head(100)
# Out:
#     DataYear        BuildingType PrimaryPropertyType  \
# 0       2015      NonResidential               Hotel
# 1       2015      NonResidential               Hotel
# 2       2015      NonResidential               Hotel
# 3       2015      NonResidential               Hotel
# 4       2015      NonResidential               Hotel
# ..       ...                 ...                 ...
# 95      2015   SPS-District K-12         K-12 School
# 96      2015      NonResidential               Hotel
# 97      2015  Nonresidential COS               Other
# 98      2015      NonResidential            Hospital
# 99      2015   SPS-District K-12         K-12 School
#
#                                     PropertyName  \
# 0                           MAYFLOWER PARK HOTEL
# 1                                PARAMOUNT HOTEL
# 2                                   WESTIN HOTEL
# 3                                      HOTEL MAX
# 4                          WARWICK SEATTLE HOTEL
# ...

# %%
y = df1.DataYear                        
list = ['YearBuilt','DataYear']
x = df1.drop(list,axis = 1 )
x.head(100)
# Out:
#     OSEBuildingID        BuildingType PrimaryPropertyType  \
# 0               1      NonResidential               Hotel
# 1               2      NonResidential               Hotel
# 2               3      NonResidential               Hotel
# 3               5      NonResidential               Hotel
# 4               8      NonResidential               Hotel
# ..            ...                 ...                 ...
# 95            140   SPS-District K-12         K-12 School
# 96            144      NonResidential               Hotel
# 97            145  Nonresidential COS               Other
# 98            147      NonResidential            Hospital
# 99            148   SPS-District K-12         K-12 School
#
#                                     PropertyName  \
# 0                           MAYFLOWER PARK HOTEL
# 1                                PARAMOUNT HOTEL
# 2                                   WESTIN HOTEL
# 3                                      HOTEL MAX
# ...

# %%
df2 = pd.read_csv('2016-building-energy-benchmarking.csv')

# %%
y = df2.OSEBuildingID                        
list = ['Zip Codes','OSEBuildingID']
x = df1.drop(list,axis = 1 )
x.head(100)
# Out:
#     DataYear        BuildingType PrimaryPropertyType  \
# 0       2015      NonResidential               Hotel
# 1       2015      NonResidential               Hotel
# 2       2015      NonResidential               Hotel
# 3       2015      NonResidential               Hotel
# 4       2015      NonResidential               Hotel
# ..       ...                 ...                 ...
# 95      2015   SPS-District K-12         K-12 School
# 96      2015      NonResidential               Hotel
# 97      2015  Nonresidential COS               Other
# 98      2015      NonResidential            Hospital
# 99      2015   SPS-District K-12         K-12 School
#
#                                     PropertyName  \
# 0                           MAYFLOWER PARK HOTEL
# 1                                PARAMOUNT HOTEL
# 2                                   WESTIN HOTEL
# 3                                      HOTEL MAX
# 4                          WARWICK SEATTLE HOTEL
# ...

# %%
df2 = pd.read_csv('2016-building-energy-benchmarking.csv')

# %%
df1.columns
# Out:
# Index(['OSEBuildingID', 'DataYear', 'BuildingType', 'PrimaryPropertyType',
#        'PropertyName', 'TaxParcelIdentificationNumber', 'Location',
#        'CouncilDistrictCode', 'Neighborhood', 'YearBuilt', 'NumberofBuildings',
#        'NumberofFloors', 'PropertyGFATotal', 'PropertyGFAParking',
#        'PropertyGFABuilding(s)', 'ListOfAllPropertyUseTypes',
#        'LargestPropertyUseType', 'LargestPropertyUseTypeGFA',
#        'SecondLargestPropertyUseType', 'SecondLargestPropertyUseTypeGFA',
#        'ThirdLargestPropertyUseType', 'ThirdLargestPropertyUseTypeGFA',
#        'YearsENERGYSTARCertified', 'ENERGYSTARScore', 'SiteEUI(kBtu/sf)',
#        'SiteEUIWN(kBtu/sf)', 'SourceEUI(kBtu/sf)', 'SourceEUIWN(kBtu/sf)',
#        'SiteEnergyUse(kBtu)', 'SiteEnergyUseWN(kBtu)', 'SteamUse(kBtu)',
#        'Electricity(kWh)', 'Electricity(kBtu)', 'NaturalGas(therms)',
#        'NaturalGas(kBtu)', 'OtherFuelUse(kBtu)',
# ...

# %%
df2.columns
# Out:
# Index(['OSEBuildingID', 'DataYear', 'BuildingType', 'PrimaryPropertyType',
#        'PropertyName', 'Address', 'City', 'State', 'ZipCode',
#        'TaxParcelIdentificationNumber', 'CouncilDistrictCode', 'Neighborhood',
#        'Latitude', 'Longitude', 'YearBuilt', 'NumberofBuildings',
#        'NumberofFloors', 'PropertyGFATotal', 'PropertyGFAParking',
#        'PropertyGFABuilding(s)', 'ListOfAllPropertyUseTypes',
#        'LargestPropertyUseType', 'LargestPropertyUseTypeGFA',
#        'SecondLargestPropertyUseType', 'SecondLargestPropertyUseTypeGFA',
#        'ThirdLargestPropertyUseType', 'ThirdLargestPropertyUseTypeGFA',
#        'YearsENERGYSTARCertified', 'ENERGYSTARScore', 'SiteEUI(kBtu/sf)',
#        'SiteEUIWN(kBtu/sf)', 'SourceEUI(kBtu/sf)', 'SourceEUIWN(kBtu/sf)',
#        'SiteEnergyUse(kBtu)', 'SiteEnergyUseWN(kBtu)', 'SteamUse(kBtu)',
#        'Electricity(kWh)', 'Electricity(kBtu)', 'NaturalGas(therms)',
# ...

# %%
pd.concat([df1, df2]).loc[df1.index.symmetric_difference(df2.index)]
# Out:
#       OSEBuildingID  DataYear          BuildingType    PrimaryPropertyType  \
# 3340          50070      2016        NonResidential                  Other
# 3341          50071      2016  Multifamily MR (5-9)   Mid-Rise Multifamily
# 3342          50072      2016  Multifamily MR (5-9)   Mid-Rise Multifamily
# 3343          50074      2016  Multifamily MR (5-9)   Mid-Rise Multifamily
# 3344          50075      2016  Multifamily MR (5-9)   Mid-Rise Multifamily
# 3345          50076      2016  Multifamily MR (5-9)   Mid-Rise Multifamily
# 3346          50078      2016  Multifamily HR (10+)  High-Rise Multifamily
# 3347          50081      2016        NonResidential            K-12 School
# 3348          50082      2016  Multifamily LR (1-4)   Low-Rise Multifamily
# 3349          50084      2016  Multifamily MR (5-9)   Mid-Rise Multifamily
# 3350          50086      2016  Multifamily LR (1-4)   Low-Rise Multifamily
# ...

# %%
df1.columns
# Out:
# Index(['OSEBuildingID', 'DataYear', 'BuildingType', 'PrimaryPropertyType',
#        'PropertyName', 'TaxParcelIdentificationNumber', 'Location',
#        'CouncilDistrictCode', 'Neighborhood', 'YearBuilt', 'NumberofBuildings',
#        'NumberofFloors', 'PropertyGFATotal', 'PropertyGFAParking',
#        'PropertyGFABuilding(s)', 'ListOfAllPropertyUseTypes',
#        'LargestPropertyUseType', 'LargestPropertyUseTypeGFA',
#        'SecondLargestPropertyUseType', 'SecondLargestPropertyUseTypeGFA',
#        'ThirdLargestPropertyUseType', 'ThirdLargestPropertyUseTypeGFA',
#        'YearsENERGYSTARCertified', 'ENERGYSTARScore', 'SiteEUI(kBtu/sf)',
#        'SiteEUIWN(kBtu/sf)', 'SourceEUI(kBtu/sf)', 'SourceEUIWN(kBtu/sf)',
#        'SiteEnergyUse(kBtu)', 'SiteEnergyUseWN(kBtu)', 'SteamUse(kBtu)',
#        'Electricity(kWh)', 'Electricity(kBtu)', 'NaturalGas(therms)',
#        'NaturalGas(kBtu)', 'OtherFuelUse(kBtu)',
# ...

# %%
df2.columns
# Out:
# Index(['OSEBuildingID', 'DataYear', 'BuildingType', 'PrimaryPropertyType',
#        'PropertyName', 'Address', 'City', 'State', 'ZipCode',
#        'TaxParcelIdentificationNumber', 'CouncilDistrictCode', 'Neighborhood',
#        'Latitude', 'Longitude', 'YearBuilt', 'NumberofBuildings',
#        'NumberofFloors', 'PropertyGFATotal', 'PropertyGFAParking',
#        'PropertyGFABuilding(s)', 'ListOfAllPropertyUseTypes',
#        'LargestPropertyUseType', 'LargestPropertyUseTypeGFA',
#        'SecondLargestPropertyUseType', 'SecondLargestPropertyUseTypeGFA',
#        'ThirdLargestPropertyUseType', 'ThirdLargestPropertyUseTypeGFA',
#        'YearsENERGYSTARCertified', 'ENERGYSTARScore', 'SiteEUI(kBtu/sf)',
#        'SiteEUIWN(kBtu/sf)', 'SourceEUI(kBtu/sf)', 'SourceEUIWN(kBtu/sf)',
#        'SiteEnergyUse(kBtu)', 'SiteEnergyUseWN(kBtu)', 'SteamUse(kBtu)',
#        'Electricity(kWh)', 'Electricity(kBtu)', 'NaturalGas(therms)',
# ...

# %%
X = df1.iloc[:, :-1].values
print(X)
# Out:
# [[1 2015 'NonResidential' ... 14.0 nan 31.0]
#  [2 2015 'NonResidential' ... 14.0 nan 31.0]
#  [3 2015 'NonResidential' ... 56.0 nan 31.0]
#  ...
#  [50057 2015 'Multifamily HR (10+)' ... 56.0 nan 7.0]
#  [50058 2015 'Multifamily LR (1-4)' ... 55.0 nan 48.0]
#  [50059 2015 'Multifamily LR (1-4)' ... 55.0 nan 48.0]]

# %%
X = df2.iloc[:, :-1].values
print(X)
# Out:
# [[1 2016 'NonResidential' ... 'Compliant' nan 249.98]
#  [2 2016 'NonResidential' ... 'Compliant' nan 295.86]
#  [3 2016 'NonResidential' ... 'Compliant' nan 2089.28]
#  ...
#  [50224 2016 'Nonresidential COS' ... 'Compliant' nan 223.54]
#  [50225 2016 'Nonresidential COS' ... 'Compliant' nan 22.11]
#  [50226 2016 'Nonresidential COS' ... 'Compliant' nan 41.27]]

# %%
Y = df1.iloc[:, -1].values
print(Y)
# Out:
# [18081 18081 18081 ... 19576 18792 18792]

# %%
Y = df2.iloc[:, -1].values
print(Y)
# Out:
# [ 2.83  2.86  2.19 ... 16.99  1.57  2.26]

# %%
df1.drop(['TaxParcelIdentificationNumber'], axis=1)
# Out:
#       OSEBuildingID  DataYear          BuildingType    PrimaryPropertyType  \
# 0                 1      2015        NonResidential                  Hotel
# 1                 2      2015        NonResidential                  Hotel
# 2                 3      2015        NonResidential                  Hotel
# 3                 5      2015        NonResidential                  Hotel
# 4                 8      2015        NonResidential                  Hotel
# ...             ...       ...                   ...                    ...
# 3335          50049      2015  Multifamily LR (1-4)   Low-Rise Multifamily
# 3336          50055      2015  Multifamily MR (5-9)   Mid-Rise Multifamily
# 3337          50057      2015  Multifamily HR (10+)  High-Rise Multifamily
# 3338          50058      2015  Multifamily LR (1-4)   Low-Rise Multifamily
# 3339          50059      2015  Multifamily LR (1-4)   Low-Rise Multifamily
#
#                     PropertyName  \
# ...

# %%
df1.drop(['2010 Census Tracts','Seattle Police Department Micro Community Policing Plan Areas','City Council Districts','SPD Beats'], axis=1)
# Out:
#       OSEBuildingID  DataYear          BuildingType    PrimaryPropertyType  \
# 0                 1      2015        NonResidential                  Hotel
# 1                 2      2015        NonResidential                  Hotel
# 2                 3      2015        NonResidential                  Hotel
# 3                 5      2015        NonResidential                  Hotel
# 4                 8      2015        NonResidential                  Hotel
# ...             ...       ...                   ...                    ...
# 3335          50049      2015  Multifamily LR (1-4)   Low-Rise Multifamily
# 3336          50055      2015  Multifamily MR (5-9)   Mid-Rise Multifamily
# 3337          50057      2015  Multifamily HR (10+)  High-Rise Multifamily
# 3338          50058      2015  Multifamily LR (1-4)   Low-Rise Multifamily
# 3339          50059      2015  Multifamily LR (1-4)   Low-Rise Multifamily
#
#                     PropertyName TaxParcelIdentificationNumber  \
# ...

# %%
df3 = df1.drop(['2010 Census Tracts','Seattle Police Department Micro Community Policing Plan Areas','City Council Districts','SPD Beats'], axis=1)

# %%
df3.columns
# Out:
# Index(['OSEBuildingID', 'DataYear', 'BuildingType', 'PrimaryPropertyType',
#        'PropertyName', 'TaxParcelIdentificationNumber', 'Location',
#        'CouncilDistrictCode', 'Neighborhood', 'YearBuilt', 'NumberofBuildings',
#        'NumberofFloors', 'PropertyGFATotal', 'PropertyGFAParking',
#        'PropertyGFABuilding(s)', 'ListOfAllPropertyUseTypes',
#        'LargestPropertyUseType', 'LargestPropertyUseTypeGFA',
#        'SecondLargestPropertyUseType', 'SecondLargestPropertyUseTypeGFA',
#        'ThirdLargestPropertyUseType', 'ThirdLargestPropertyUseTypeGFA',
#        'YearsENERGYSTARCertified', 'ENERGYSTARScore', 'SiteEUI(kBtu/sf)',
#        'SiteEUIWN(kBtu/sf)', 'SourceEUI(kBtu/sf)', 'SourceEUIWN(kBtu/sf)',
#        'SiteEnergyUse(kBtu)', 'SiteEnergyUseWN(kBtu)', 'SteamUse(kBtu)',
#        'Electricity(kWh)', 'Electricity(kBtu)', 'NaturalGas(therms)',
#        'NaturalGas(kBtu)', 'OtherFuelUse(kBtu)',
# ...

# %%
df1.columns
# Out:
# Index(['OSEBuildingID', 'DataYear', 'BuildingType', 'PrimaryPropertyType',
#        'PropertyName', 'TaxParcelIdentificationNumber', 'Location',
#        'CouncilDistrictCode', 'Neighborhood', 'YearBuilt', 'NumberofBuildings',
#        'NumberofFloors', 'PropertyGFATotal', 'PropertyGFAParking',
#        'PropertyGFABuilding(s)', 'ListOfAllPropertyUseTypes',
#        'LargestPropertyUseType', 'LargestPropertyUseTypeGFA',
#        'SecondLargestPropertyUseType', 'SecondLargestPropertyUseTypeGFA',
#        'ThirdLargestPropertyUseType', 'ThirdLargestPropertyUseTypeGFA',
#        'YearsENERGYSTARCertified', 'ENERGYSTARScore', 'SiteEUI(kBtu/sf)',
#        'SiteEUIWN(kBtu/sf)', 'SourceEUI(kBtu/sf)', 'SourceEUIWN(kBtu/sf)',
#        'SiteEnergyUse(kBtu)', 'SiteEnergyUseWN(kBtu)', 'SteamUse(kBtu)',
#        'Electricity(kWh)', 'Electricity(kBtu)', 'NaturalGas(therms)',
#        'NaturalGas(kBtu)', 'OtherFuelUse(kBtu)',
# ...

# %%
df1.drop(['2010 Census Tracts','Seattle Police Department Micro Community Policing Plan Areas','City Council Districts','SPD Beats'], axis=1)
# Out:
#       OSEBuildingID  DataYear          BuildingType    PrimaryPropertyType  \
# 0                 1      2015        NonResidential                  Hotel
# 1                 2      2015        NonResidential                  Hotel
# 2                 3      2015        NonResidential                  Hotel
# 3                 5      2015        NonResidential                  Hotel
# 4                 8      2015        NonResidential                  Hotel
# ...             ...       ...                   ...                    ...
# 3335          50049      2015  Multifamily LR (1-4)   Low-Rise Multifamily
# 3336          50055      2015  Multifamily MR (5-9)   Mid-Rise Multifamily
# 3337          50057      2015  Multifamily HR (10+)  High-Rise Multifamily
# 3338          50058      2015  Multifamily LR (1-4)   Low-Rise Multifamily
# 3339          50059      2015  Multifamily LR (1-4)   Low-Rise Multifamily
#
#                     PropertyName TaxParcelIdentificationNumber  \
# ...

# %%
# seaborn histogram 
sns.catplot(x="BuildingType", kind="count",height=6, aspect=2,data=df1)
#Catplot Python Seaborn: One Function to Rule All Plots With Categorical Variables

# %%
#seaborn Scatterplot
#(z-score )normalization is applied on "TotalGHGEmissions"
plt.figure(figsize=(15,7))
df1["GHGEmissions(MetricTonsCO2e)"]=(df1["GHGEmissions(MetricTonsCO2e)"]-df1["GHGEmissions(MetricTonsCO2e)"].mean())/df1["GHGEmissions(MetricTonsCO2e)"].std()
sns.scatterplot(x=df1['BuildingType'], y=df1['GHGEmissions(MetricTonsCO2e)'])
#NonResidentials buildings are higher in GHGEmissions(MetricTonsCO2e)

# %%
df1_nr=df1[(df1['BuildingType'] =='NonResidential') ]

# %%
df1_nr.head()
# Out:
#    OSEBuildingID  DataYear    BuildingType PrimaryPropertyType  \
# 0              1      2015  NonResidential               Hotel
# 1              2      2015  NonResidential               Hotel
# 2              3      2015  NonResidential               Hotel
# 3              5      2015  NonResidential               Hotel
# 4              8      2015  NonResidential               Hotel
#
#             PropertyName TaxParcelIdentificationNumber  \
# 0   MAYFLOWER PARK HOTEL                     659000030
# 1        PARAMOUNT HOTEL                     659000220
# 2           WESTIN HOTEL                     659000475
# 3              HOTEL MAX                     659000640
# 4  WARWICK SEATTLE HOTEL                     659000970
#
#                                             Location  CouncilDistrictCode  \
# 0  {'latitude': '47.61219025', 'longitude': '-122...                    7
# 1  {'latitude': '47.61310583', 'longitude': '-122...                    7
# ...

# %%
df1["GHGEmissionsIntensity(kgCO2e/ft2)"]=(df1["GHGEmissionsIntensity(kgCO2e/ft2)"])/df1["GHGEmissionsIntensity(kgCO2e/ft2)"].max()
plt.figure(figsize=(15,8))
sns.lineplot(x='BuildingType',y='GHGEmissionsIntensity(kgCO2e/ft2)', data=df1)
#line_plot

# %%
plt.figure(figsize=(15,10))
df1["GHGEmissions(MetricTonsCO2e)"]=(df1["GHGEmissions(MetricTonsCO2e)"])/df1["GHGEmissions(MetricTonsCO2e)"].max()
sns.boxplot(y ='GHGEmissions(MetricTonsCO2e)',data= df1, x= 'BuildingType')
plt.xlabel('BuildingType')
## Multifamily MR (5-9),SPS-District K-12 , Multifamily LR (1-4), have almost same mean
# Out:
# Text(0.5, 0, 'BuildingType')

# %%
plt.scatter(df1["NaturalGas(kBtu)"],df1["GHGEmissions(MetricTonsCO2e)"],  color='blue')
plt.xlabel("NaturalGas(kBtu)")
plt.ylabel("GHGEmissions(MetricTonsCO2e)")
plt.show()

# %%
df1.drop(['2010 Census Tracts','Seattle Police Department Micro Community Policing Plan Areas','City Council Districts','SPD Beats'], axis=1)
# Out:
#       OSEBuildingID  DataYear          BuildingType    PrimaryPropertyType  \
# 0                 1      2015        NonResidential                  Hotel
# 1                 2      2015        NonResidential                  Hotel
# 2                 3      2015        NonResidential                  Hotel
# 3                 5      2015        NonResidential                  Hotel
# 4                 8      2015        NonResidential                  Hotel
# ...             ...       ...                   ...                    ...
# 3335          50049      2015  Multifamily LR (1-4)   Low-Rise Multifamily
# 3336          50055      2015  Multifamily MR (5-9)   Mid-Rise Multifamily
# 3337          50057      2015  Multifamily HR (10+)  High-Rise Multifamily
# 3338          50058      2015  Multifamily LR (1-4)   Low-Rise Multifamily
# 3339          50059      2015  Multifamily LR (1-4)   Low-Rise Multifamily
#
#                     PropertyName TaxParcelIdentificationNumber  \
# ...
